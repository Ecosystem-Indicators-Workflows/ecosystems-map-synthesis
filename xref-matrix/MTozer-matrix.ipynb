# %% [markdown]
# # National ecosystem inventory

# %% [markdown]
# ## Download cross-referencing tables

# %% [markdown]
# Process/rationale of the cross-reference is documented in Marks Tozer's Notebooks and will be shared later.
#
# ::: {.callout-caution}
# These files have been shared directly by the author and are not available from public sources. This data source cannot be integrated into the reproducible workflow.
# :::

# %%
REPODIR=$(pwd)/..
mkdir -p $REPODIR/gisdata/
unzip -u ~/Downloads/Cross_refs.zip -d $REPODIR/gisdata/
# Out:
# Archive:  /home/jferrer/Downloads/Cross_refs.zip

# %% [markdown]
# These files are available for different states, with several authors involved:
# - MGT: Mark Tozer
# - DAK: David A Keith
# - Eda:

# %%
tree -L 3 $REPODIR/gisdata/Cross_refs
# Out:
# /home/jferrer/proyectos/EIW/ecosystems-map-synthesis/xref-matrix/../gisdata/Cross_refs
# ├── Northern_Territory
# │   └── MGT
# │       └── ntveg_1M_290925_MGT.csv
# ├── NSW
# │   └── MGT
# │       └── bionet-plant-community-type-data_MGT_290426.csv
# ├── Queensland
# │   ├── DAK
# │   │   ├── QLD_RE_GET3_crossref_DAK_300326.csv
# │   │   └── QLD_RE_GET3_crossref.xlsx
# │   ├── Eda
# │   │   ├── CYP_bioregion_GET_cross-walk_EA26042026
# │   │   ├── EIU_bioregion_GET_cross-walk_EA26042026
# │   │   ├── notes.docx
# │   │   └── WET_bioregion_GET_cross-walk_EA26042026
# │   └── MGT
# │       └── QLD_RE_GET3_crossref_MGT_171025.csv
# ├── Savanna_RE_GET3_crossref
# │   └── MGT
# │       └── Savanna_GET3_crossref_MGT_120925.csv
# ├── South_Australia
# │   ├── DAK
# │   │   ├── ecosystemsDesc.csv
# │   │   └── VEG_PEVegetation_GET_DK.xlsx
# │   └── MGT
# │       ├── SA_ecosystemsDesc_MGT_GET3_170426.csv
# │       └── VEG_PEVegetation_GET_MGT170426.csv
# ├── Tasmania
# │   └── MGT
# ...
