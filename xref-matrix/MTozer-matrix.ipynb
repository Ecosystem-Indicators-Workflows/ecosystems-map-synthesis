# %% [markdown]
# # National ecosystem inventory

# %% [markdown]
# ## Download cross-referencing table

# %% [markdown]
# Process/rationale of the cross-reference is documented in Marks Tozer's Notebooks and will be shared later. We are using a version from June 2025.
#
# ::: {.callout-caution}
# This dataset has been shared directly by the author and is not available from public sources. This data source cannot be integrated into the reproducible workflow.
# :::

# %%
ls $REPODIR/gisdata/xrefdata/QLD_crossref_MGT_270625_fixed.csv
